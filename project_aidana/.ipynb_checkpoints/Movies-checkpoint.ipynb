# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Walt_disney_movie_dataset.csv")

# %%
df
# Out:
#      Unnamed: 0                            title       Production company  \
# 0             0          Academy Award Review of  Walt Disney Productions
# 1             1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2             2                        Pinocchio  Walt Disney Productions
# 3             3                         Fantasia  Walt Disney Productions
# 4             4             The Reluctant Dragon  Walt Disney Productions
# ..          ...                              ...                      ...
# 447         447     Chip 'n Dale: Rescue Rangers                      NaN
# 448         448                      Hocus Pocus     Walt Disney Pictures
# 449         449                           Shrunk                      NaN
# 450         450                        Pinocchio                      NaN
# 451         451               Hollywood Stargirl                      NaN
#
#                                           Release date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               452 non-null    int64
#  1   title                    452 non-null    object
#  2   Production company       190 non-null    object
#  3   Release date             447 non-null    object
#  4   Running time             440 non-null    object
#  5   Country                  403 non-null    object
#  6   Language                 433 non-null    object
#  7   Box office               372 non-null    object
#  8   Running time (int)       440 non-null    float64
#  9   Budget (float)           284 non-null    float64
#  10  Box office (float)       365 non-null    float64
#  11  Release date (datetime)  442 non-null    object
#  12  Directed by              451 non-null    object
#  13  Written by               204 non-null    object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#                                         Release date  \
# 0                                   ['May 19, 1937']
# 1   ['December 21, 1937 ( Carthay Circle Theatre )']
# 2  ['February 7, 1940 ( Center Theatre )', 'Febru...
# 3                              ['November 13, 1940']
# 4                                  ['June 27, 1941']
#
#                            Running time        Country Language  \
# 0  41 minutes (74 minutes 1966 release)  United States  English
# 1                            83 minutes  United States  English
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Running time (int)  Budget (float)  Box office (float)  \
# count  452.000000          440.000000    2.840000e+02        3.650000e+02
# mean   225.500000           97.813636    6.387747e+07        1.659321e+08
# std    130.625419           18.958576    7.143128e+07        2.712141e+08
# min      0.000000           40.000000    3.000000e+05        7.700000e+00
# 25%    112.750000           86.750000    1.100000e+07        1.050000e+07
# 50%    225.500000           96.000000    3.000000e+07        4.490000e+07
# 75%    338.250000          107.000000    1.000000e+08        1.861000e+08
# max    451.000000          167.000000    4.106000e+08        1.657000e+09
#
#        Japanese  Traditional  Simplified
# count       0.0          0.0         0.0
# mean        NaN          NaN         NaN
# std         NaN          NaN         NaN
# min         NaN          NaN         NaN
# 25%         NaN          NaN         NaN
# 50%         NaN          NaN         NaN
# ...

# %%
# listing all the columns name
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'Production company', 'Release date',
#        'Running time', 'Country', 'Language', 'Box office',
#        'Running time (int)', 'Budget (float)', 'Box office (float)',
#        'Release date (datetime)', 'Directed by', 'Written by', 'Based on',
#        'Produced by', 'Starring', 'Music by', 'Distributed by', 'Budget',
#        'Story by', 'Narrated by', 'Cinematography', 'Edited by', 'Languages',
#        'Screenplay by', 'Countries', 'Production companies', 'Color process',
#        'Japanese', 'Hepburn', 'Adaptation by', 'Animation by', 'Traditional',
#        'Simplified'],
#       dtype='object')

# %%
df[['title', 'Budget']].sort_values('title', ascending=False).head(10)

# cheking most popula title
# Out:
#                                     title                       Budget
# 329                        Книга Мастеров  $8 million ( ₽ 350 million)
# 387                              Zootopia                 $150 million
# 348                              Zokkomon                          NaN
# 362                        Wreck-It Ralph                 $165 million
# 353                       Winnie the Pooh                  $30 million
# 364                         Wings of Life                          NaN
# 174           Wild Hearts Can't Be Broken                          NaN
# 38                       White Wilderness                          NaN
# 191  White Fang 2: Myth of the White Wolf                          NaN
# 172                            White Fang                  $14 million

# %%
print(df[['Production company']].value_counts())
# Out:
# Production company
# Walt Disney Productions                                151
# Walt Disney Pictures                                    31
# Studio Ghibli                                            5
# Disneynature                                             2
# Walt Disney Productions Robert Lawrence Productions      1
# dtype: int64

# %%
df[['title','Box office']].sort_values('Box office', ascending=False).head(10)

# highest grossing movies of all time
# Out:
#                                   title  \
# 375                          Khoobsurat
# 71                    The Moon-Spinners
# 68                        A Tiger Walks
# 384                              ABCD 2
# 436      The Last Warrior: Root of Evil
# 284                Howl's Moving Castle
# 396                              Dangal
# 42   Darby O'Gill and the Little People
# 113                  Herbie Rides Again
# 141                      The Black Hole
#
#                                             Box office
# 375                               est. (US$11 million)
# 71                        est. $3,500,000 (US/ Canada)
# 68                        est. $1,600,000 (US/ Canada)
# 384                                               est.
# 436  ['₽ 2.046 billion', '$28.3 million (Worldwide)...
# 284  ['¥', '23.2 billion', 'US$236 million (worldwi...
# 396                                 ['est.', '(', ')']
# 42   ['Original release', ':', '$2.6 million (est. ...
# ...

# %%
rich_movies = df[['title','Box office']].sort_values('Box office', ascending=False).head(10)
print(rich_movies)
# Out:
#                                   title  \
# 375                          Khoobsurat
# 71                    The Moon-Spinners
# 68                        A Tiger Walks
# 384                              ABCD 2
# 436      The Last Warrior: Root of Evil
# 284                Howl's Moving Castle
# 396                              Dangal
# 42   Darby O'Gill and the Little People
# 113                  Herbie Rides Again
# 141                      The Black Hole
#
#                                             Box office
# 375                               est. (US$11 million)
# 71                        est. $3,500,000 (US/ Canada)
# 68                        est. $1,600,000 (US/ Canada)
# 384                                               est.
# 436  ['₽ 2.046 billion', '$28.3 million (Worldwide)...
# 284  ['¥', '23.2 billion', 'US$236 million (worldwi...
# 396                                 ['est.', '(', ')']
# 42   ['Original release', ':', '$2.6 million (est. ...
# ...

# %%
sns.heatmap(df.isnull()) ## Correlation between missing values per columns
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize= (15,15))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Running time (int)'}>,
#         <AxesSubplot:title={'center':'Budget (float)'}>],
#        [<AxesSubplot:title={'center':'Box office (float)'}>,
#         <AxesSubplot:title={'center':'Japanese'}>,
#         <AxesSubplot:title={'center':'Traditional'}>],
#        [<AxesSubplot:title={'center':'Simplified'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)
