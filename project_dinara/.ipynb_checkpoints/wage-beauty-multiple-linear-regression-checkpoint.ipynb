# %%
dataset <- read.csv("../input/beauty.csv", sep = ",", header = TRUE)
summary(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4g/x966n1ts5w7f78pg2515mz800000gn/T/ipykernel_6528/3472499663.py in <module>
# ----> 1 dataset <- read.csv("beauty.csv", sep = ",", header = TRUE)
#       2 summary(dataset)
#
# NameError: name 'dataset' is not defined

# %%
matrix <- cor(dataset)
library(corrplot)
corrplot(matrix, method="number")
# Out:
# corrplot 0.84 loaded

# %%
library(regclass)
VIF(lm(wage ~ ., data = dataset))
# Out:
# Loading required package: bestglm
# Loading required package: leaps
# Loading required package: VGAM
# Loading required package: stats4
# Loading required package: splines
# Loading required package: rpart
# Loading required package: randomForest
# randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.
# Important regclass change from 1.3:
# All functions that had a . in the name now have an _
# all.correlations -> all_correlations, cor.demo -> cor_demo, etc.
#    exper    union goodhlth    black   female  married  service     educ
# 1.189538 1.027303 1.033280 1.051016 1.269719 1.173397 1.208295 1.207297
#    looks
# 1.047146

# %%
dataset[2:10] <- scale(dataset[2:10])
summary(dataset)
# Out:
#       wage            exper             union            goodhlth
#  Min.   : 1.020   Min.   :-1.5218   Min.   :-0.6114   Min.   :-3.7402
#  1st Qu.: 3.708   1st Qu.:-0.8531   1st Qu.:-0.6114   1st Qu.: 0.2672
#  Median : 5.300   Median :-0.2680   Median :-0.6114   Median : 0.2672
#  Mean   : 6.307   Mean   : 0.0000   Mean   : 0.0000   Mean   : 0.0000
#  3rd Qu.: 7.695   3rd Qu.: 0.7350   3rd Qu.: 1.6344   3rd Qu.: 0.2672
#  Max.   :77.720   Max.   : 2.4904   Max.   : 1.6344   Max.   : 0.2672
#      black             female           married          service
#  Min.   :-0.2822   Min.   :-0.7271   Min.   :-1.496   Min.   :-0.6138
#  1st Qu.:-0.2822   1st Qu.:-0.7271   1st Qu.:-1.496   1st Qu.:-0.6138
#  Median :-0.2822   Median :-0.7271   Median : 0.668   Median :-0.6138
#  Mean   : 0.0000   Mean   : 0.0000   Mean   : 0.000   Mean   : 0.0000
#  3rd Qu.:-0.2822   3rd Qu.: 1.3742   3rd Qu.: 0.668   3rd Qu.: 1.6279
#  Max.   : 3.5410   Max.   : 1.3742   Max.   : 0.668   Max.   : 1.6279
#       educ             looks
#  Min.   :-2.8819   Min.   :-3.1914
#  1st Qu.:-0.2147   1st Qu.:-0.2712
#  Median :-0.2147   Median :-0.2712
#  Mean   : 0.0000   Mean   : 0.0000
#  3rd Qu.: 0.1663   3rd Qu.: 1.1890
#  Max.   : 1.6904   Max.   : 2.6491

# %%
library(caTools)
set.seed(123)
split = sample.split(dataset$wage, SplitRatio = 0.75)
train_set = subset(dataset, split == TRUE)
test_set = subset(dataset, split == FALSE)

# %%
regressor = lm(formula = wage ~ ., data = train_set)
summary(regressor)
# Out:
# Call:
# lm(formula = wage ~ ., data = train_set)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -7.179 -2.252 -0.580  1.137 72.466
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  6.40421    0.13553  47.254  < 2e-16 ***
# exper        1.01917    0.14825   6.875 1.06e-11 ***
# union        0.33538    0.13692   2.449  0.01447 *
# goodhlth    -0.04122    0.13541  -0.304  0.76086
# black        0.02440    0.13707   0.178  0.85876
# female      -1.03132    0.15465  -6.669 4.17e-11 ***
# married      0.39322    0.14701   2.675  0.00759 **
# service     -0.25786    0.14743  -1.749  0.08057 .
# educ         1.28297    0.14654   8.755  < 2e-16 ***
# looks        0.31262    0.13778   2.269  0.02347 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.399 on 1047 degrees of freedom
# Multiple R-squared:  0.1973,	Adjusted R-squared:  0.1904
# F-statistic:  28.6 on 9 and 1047 DF,  p-value: < 2.2e-16

# %%
y_pred = predict(regressor, newdata = test_set)

# %%
plot(test_set$wage, y_pred, col='blue', pch=16, ylab = "predicted wage", xlab = "real wage")
abline(0,1, col = "red")

# %%
RMSE = (sum((test_set$wage - y_pred)^2) / nrow(dataset)) ^ 0.5
print(paste0("Root Mean Square Error is ", RMSE))
# Out:
# [1] "Root Mean Square Error is 1.11988559147154"

# %%
hist(y_pred, xlim = c(0,15), ylim = c(0,40),
     xlab = "Predicted wage", ylab = "Percentage", main = "Histogram of predicted values",
     col = "skyblue", border = "purple", density = 30)
